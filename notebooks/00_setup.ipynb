# %%
#CELL 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

#Creating Project Folder in drive
import os
PROJECT_DIR = '/content/drive/MyDrive/MusicGenerationCSE425'
os.makedirs(PROJECT_DIR, exist_ok=True)
print(f"Project directory: {PROJECT_DIR}")
# Out:
# Mounted at /content/drive
# Project directory: /content/drive/MyDrive/MusicGenerationCSE425

# %%
#CELL 1: Library installation
# !pip install pretty_midi miditok tqdm -q

#Verify installations
import pretty_midi
import miditok
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("pretty_midi version:", pretty_midi.__version__)
print("torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("All libraries loaded successfully!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 81.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.0/159.0 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 62.8 MB/s eta 0:00:00
# ...
# pretty_midi version: 0.2.11
# torch version: 2.10.0+cpu
# CUDA available: False
# All libraries loaded successfully!

# %%
#CELL 2: Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
import os

# Define all directory paths used across notebooks
PROJECT_DIR = '/content/drive/MyDrive/MusicGenerationCSE425'
DATA_DIR      = f'{PROJECT_DIR}/data'
RAW_MIDI_DIR  = f'{DATA_DIR}/raw_midi'
PROCESSED_DIR = f'{DATA_DIR}/processed'
MODELS_DIR    = f'{PROJECT_DIR}/models_saved'
OUTPUTS_DIR   = f'{PROJECT_DIR}/outputs'
PLOTS_DIR     = f'{OUTPUTS_DIR}/plots'
MIDI_OUT_DIR  = f'{OUTPUTS_DIR}/generated_midis'

# Create all directories
for d in [DATA_DIR, RAW_MIDI_DIR, PROCESSED_DIR, MODELS_DIR,
          OUTPUTS_DIR, PLOTS_DIR, MIDI_OUT_DIR]:
    os.makedirs(d, exist_ok=True)

print("All directories created:")
for d in [DATA_DIR, RAW_MIDI_DIR, PROCESSED_DIR, MODELS_DIR, OUTPUTS_DIR]:
    print(f"   {d}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All directories created:
#    /content/drive/MyDrive/MusicGenerationCSE425/data
#    /content/drive/MyDrive/MusicGenerationCSE425/data/raw_midi
#    /content/drive/MyDrive/MusicGenerationCSE425/data/processed
#    /content/drive/MyDrive/MusicGenerationCSE425/models_saved
#    /content/drive/MyDrive/MusicGenerationCSE425/outputs

# %%
#CELL 3: Set random seeds for reproducibility
import random
import torch
import numpy as np

SEED = 42

def set_seed(seed=SEED):
    """Fix random seeds for reproducibility across all libraries."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    print(f" Random seed set to {seed}")

set_seed()

# Device configuration use GPU if available
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")
# Out:
#  Random seed set to 42
# Using device: cpu
